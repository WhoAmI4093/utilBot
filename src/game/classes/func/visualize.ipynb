# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.array([
    [1, 360],
    [2, 180],
    [3, 120],
    [4, 90],
    [5, 72],
    [6, 60],
    [8, 45],
    [12, 30],
    [24, 15]
])

# %%
x, y = data.T
plt.plot(x,y)
plt.axis('equal')
plt.show()
